# %%
#First we want to connect and import the packages needed
import pymmcore_plus
from pymmcore_plus import CMMCorePlus
from useq import MDAEvent
from useq import MDASequence
import useq
import numpy as np
import tifffile as tiff
from pymmcore_gui import create_mmgui
from pymmcore_gui._qt.QtWidgets import QApplication

# (you do not need to create a QApplication instance)

window = create_mmgui(exec_app=False)

# customize the app or do other setup here
# mmcore = window.mmcore  # access the CMMCorePlus used by the GUI

mmc = window.mmcore
mmc.loadSystemConfiguration(r"\Users\Hannah\AppData\Local\pymmcore-plus\pymmcore-plus\mm\Micro-Manager_2.0.3_20260608\configuration\Configuration_new.cfg")  
# Load the correct configuration file. NB! If a new configuration file is created, change the path to the new configuration file
mmc.setProperty('NIDAQAO-Dev1/ao0','Voltage',0.725)
mmc.getProperty('NIDAQAO-Dev1/ao0','Voltage')
#mmc.setProperty('Camera-1','PreampOffLimit', 10000)
#mmc.setProperty('NIDAQDO-Dev1/port0','State',0)
mmc.setProperty('NIDAQHub','Sequence','On')
mmc.loadPropertySequence("NIDAQAO-Dev1/ao0", "Voltage", ['0.4', '0.5', '0.6', '0.7', '0.8', '0.9'])

# %%
QApplication.instance().exec()  # Start the Qt event loop

# %%
mmc.setProperty('Camera-1','PreampOffLimit', 10000)
mmc.setProperty('NIDAQDO-Dev1/port0','State',0)

# %%
for prop in mmc.getDevicePropertyNames("Camera-1"):  # adjust device name as needed
    print(mmc.getAllowedPropertyValues("Camera-1", prop))
    print(prop, ":", mmc.getProperty("Camera-1", prop))
for prop in mmc.getDevicePropertyNames("NIDAQDO-Dev1/port0"):  # adjust device name as needed
    print(mmc.getAllowedPropertyValues("NIDAQDO-Dev1/port0", prop))
    print(prop, ":", mmc.getProperty("NIDAQDO-Dev1/port0", prop))
