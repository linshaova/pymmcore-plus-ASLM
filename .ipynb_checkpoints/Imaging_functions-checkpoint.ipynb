# %%
#We start by importing the required packages. These are used in the following function.
import pymmcore_plus
from pymmcore_plus import CMMCorePlus
from useq import MDAEvent
from useq import MDASequence
import useq
import numpy as np
import tifffile as tiff
import time
from pathlib import Path

# %%
#Let's first define an initialize function which will customize the acquisition engine, to what we need it to do
def initialize(config ='Configuration_main.cfg', start_V = 0.725)
    path =Path(fr"C:\\Users\\Hannah\\AppData\\Local\\pymmcore-plus\\pymmcore-plus\\mm\\Micro-Manager_2.0.3_20260429\\configuration\\{config}")
    
    if false in path.exists():
        print('Configuration file not found. Make sure it is in folder: C:\\Users\\Hannah\\AppData\\Local\\pymmcore-plus\\pymmcore-plus\\mm\\Micro-Manager_2.0.3_20260429\\configuration')
        return
    
    # Create the core instance.
    mmc = CMMCorePlus.instance()
    # Load the correct configuration file. NB! If a new configuration file is created, change the path to the new configuration file
    mmc.loadSystemConfiguration(path)
    
    if ['NIDAQAO-Dev1/ao0'] or ['Camera-1'] not in [mmc.getLoadedDevices()]
        if ['NIDAQAO-Dev1/ao0'] not in [mmc.getLoadedDevices()]
            print('The Voice coil pin on the DAQ card wa
                  s not found!')
        if ['Camera-1'] not in [mmc.getLoadedDevices()]
            print('The Camera was not found!')
        return
    
    if start_V > 1
        print('The starting voltage is too high. Remember the voltage range is 0-1 V! Excess voltage could damage the voice coil!')
        return
        
    if start_V < 0
        print('The starting voltage is negative. Remember the voltage range is 0-1 V! Excess voltage could damage the voice coil!')
        return
        
    mmc.setProperty('NIDAQAO-Dev1/ao0','Voltage',start_V)

    @mmc.mda.events.frameReady.connect 
    def on_frame(image: np.ndarray, event: useq.MDAEvent, meta: pymmcore_plus.metadata.FrameMetaV1):
    # do what you want with the data
        print(
            f"received frame: {image.shape}, {image.dtype} "
        )
        tiff.imwrite(f"{event.metadata['path']}\\temp{event.metadata['idx']}.tif", image, photometric='minisblack')
    return print(f"Initialization is complete.")

def

# %%
# Out:
# C:\Users\Hannah\AppData\Local\pymmcore-plus\pymmcore-plus\mm\Micro-Manager_2.0.3_20260429\configuration
# True
