# %%
#First we want to connect and import the packages needed
import pymmcore_plus
from pymmcore_plus import CMMCorePlus
from useq import MDAEvent
from useq import MDASequence
import useq
import numpy as np
import tifffile as tiff
import time
# Create the core instance.
mmc = CMMCorePlus.instance()
# Load the correct configuration file. NB! If a new configuration file is created, change the path to the new configuration file
mmc.loadSystemConfiguration(r"\Users\Hannah\AppData\Local\pymmcore-plus\pymmcore-plus\mm\Micro-Manager_2.0.3_20260429\configuration\Configuration_main.cfg")  
mmc.setProperty('NIDAQAO-Dev1/ao0','Voltage',0.725)
mmc.getProperty('NIDAQAO-Dev1/ao0','Voltage')
print(mmc.getLoadedDevices())    # lists all loaded device labels
print(mmc.getCameraDevice())     # should be one of those labels  
mmc.setAutoShutter(False)
# Out:
# ('Camera-1', 'NIDAQHub', 'NIDAQAO-Dev1/ao0', 'NIDAQDO-Dev1/port2', 'Core')
# Camera-1

# %%
# Create a super-simple sequence, with one event

@mmc.mda.events.frameReady.connect 
def on_frame(image: np.ndarray, event: useq.MDAEvent, metadata: dict):
    # do what you want with the data
    print(
        f"received frame: {image.shape}, {image.dtype} "
        f"@ index {event.index}"
        f"meta{metadata}"
    )
    tiff.imwrite(f"temp.tif", image, photometric='minisblack')


tup = [('NIDAQAO-Dev1/ao0','Voltage',0.85)]
mda_sequence = [MDAEvent(properties=tup)] 
# Run it!
mmc.run_mda(mda_sequence)
time.sleep(5)

tup = [('NIDAQAO-Dev1/ao0','Voltage',0.65)]
mda_sequence = [MDAEvent(properties=tup)] 
# Run it!
mmc.run_mda(mda_sequence)

# %%
V = [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
n = len(V)


@mmc.mda.events.frameReady.connect 
def on_frame(image: np.ndarray, event: useq.MDAEvent, meta: pymmcore_plus.metadata.FrameMetaV1):
    # do what you want with the data
    print(
        f"received frame: {image.shape}, {image.dtype} "
        f"metadata: {meta['mda_event']}"
    )
    tiff.imwrite(f"{event.metadata['path']}\\temp{event.metadata['idx']}.tif", image, photometric='minisblack')

mda_sequence_5=[]
for i in range(n):
    mda_sequence_5 +=[MDAEvent(exposure=100,properties=[('NIDAQAO-Dev1/ao0','Voltage',V[i])],metadata = {'idx': i, 'path': r'C:\Users\Hannah\Pymmcore_plus_scripts\5-29-2026'})]
mmc.run_mda(mda_sequence_5)
# Out:
# <Thread(Thread-3 (run), started 10316)>
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.4)] metadata={'idx': 0, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.45)] metadata={'idx': 1, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.5)] metadata={'idx': 2, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.55)] metadata={'idx': 3, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.6)] metadata={'idx': 4, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.65)] metadata={'idx': 5, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.7)] metadata={'idx': 6, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.75)] metadata={'idx': 7, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.8)] metadata={'idx': 8, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.85)] metadata={'idx': 9, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}
# received frame: (3200, 3200), uint16 metadata: exposure=100.0 properties=[PropertyTuple(device_name='NIDAQAO-Dev1/ao0', property_name='Voltage', property_value=0.9)] metadata={'idx': 10, 'path': 'C:\\Users\\Hannah\\Pymmcore_plus_scripts\\5-29-2026'}

# %%
try:
    device.load('NIDAQ','NIDAQAO-Dev1-ao0','NIDAQAO')
    print(device.isLoaded())
    device.initialize
    print(device.properties)
    print(device.schema())
    print(device.isLoaded())
    device.load('NIDAQ','NIDAQHub')
    print(device.isLoaded())
    print(device.properties)
    print(device.detect())
    device.unload()
except:
    device.unload()
    print('Error happened')

# %%
try:
    properties = mmc.getDevicePropertyNames('NIDAQAO-Dev1/ao0')
    print(properties)
    for i in range(0,len(properties)):
        print(mmc.getProperty('NIDAQAO-Dev1/ao0',properties[i]))
        print(mmc.isPropertySequenceable('NIDAQAO-Dev1/ao0',properties[i]))
    volts = ['0.4', '0.5', '0.6', '0.7', '0.8', '0.9']
    mmc.setProperty('NIDAQHub','Sequence','On')
    properties2 = mmc.getDevicePropertyNames('NIDAQHub')
    print(properties2)
    for i in range(0,len(properties2)):
        print(mmc.getProperty('NIDAQHub',properties2[i]))
        print(mmc.isPropertySequenceable('NIDAQHub',properties2[i]))
    mmc.setProperty('NIDAQHub','Sequence','Off')
    mmc.setProperty('NIDAQHub','SampleRateHz','10000')
    
except:
    mmc.setProperty('NIDAQHub','Sequence','Off')
    mmc.setProperty('NIDAQHub','SampleRateHz','10000')
    print('oops')

# %%
f"temp{MDAEvent.index}"

# %%
mmc.mda.cancel()

# %%
properties = mmc.getDevicePropertyNames('Camera-1')
print(properties)
# Out:
# ('ActualInterval-ms', 'Binning', 'CCDTemperature', 'CCDTemperatureSetPoint', 'ChipName', 'CircularBufferAutoSize', 'CircularBufferEnabled', 'CircularBufferFrameCount', 'CircularBufferFrameRecovery', 'ClearCycles', 'ClearMode', 'Color', 'Description', 'DiskStreamingCoreSkipRatio', 'DiskStreamingEnabled', 'DiskStreamingPath', 'ExposeOutMode', 'Exposure', 'FTCapable', 'FanSpeedSetpoint', 'FirmwareVersion', 'FullWellCapacity', 'Gain', 'MetadataEnabled', 'Name', 'Offset', 'PMode', 'PP  0 DESPECKLE BRIGHT LOW', 'PP  1   ENABLED', 'PP  1   THRESHOLD', 'PP  1 DESPECKLE BRIGHT HIGH', 'PP  2   ENABLED', 'PP  2   MIN ADU AFFECTED', 'PP  2   THRESHOLD', 'PP  2 DESPECKLE DARK LOW', 'PP  3   ENABLED', 'PP  3   THRESHOLD', 'PP  3 DESPECKLE DARK HIGH', 'PP  4   ENABLED', 'PP  4   MIN ADU AFFECTED', 'PP  4   THRESHOLD', 'PP  5 Reset', 'PVCAM Adapter Version', 'PVCAM Version', 'PixelType', 'Port', 'PreampDelay', 'PreampOffLimit', 'ReadoutRate', 'SMARTStreamingEnabled', 'SMARTStreamingValues[ms]', 'ScanDirection', 'ScanDirectionReset', 'ScanLineDelay', 'ScanLineTime', 'ScanMode', 'ScanWidth', 'SerialNumber', 'ShutterCloseDelay', 'ShutterMode', 'ShutterOpenDelay', 'Timing-ClearingTimeNs', 'Timing-ExposureTimeNs', 'Timing-PostTriggerDelayNs', 'Timing-PreTriggerDelayNs', 'Timing-ReadoutTimeNs', 'TransposeCorrection', 'TransposeMirrorX', 'TransposeMirrorY', 'TransposeXY', 'Trigger Timeout (secs)', 'Trigger-Expose Out-Mux', 'TriggerMode', 'X-dimension', 'Y-dimension')
